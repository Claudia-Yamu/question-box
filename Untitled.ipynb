# %%
# !jupyter nbconvert --to script query_test.ipynb
# Out:
# [NbConvertApp] Converting notebook query_test.ipynb to script
# [NbConvertApp] Writing 1537 bytes to query_test.py

# %%
# !jupyter nbconvert --to script extract_html.ipynb
# Out:
# [NbConvertApp] Converting notebook extract_html.ipynb to script
# [NbConvertApp] Writing 2327 bytes to extract_html.py

# %%
import os

print(os.getcwd())

print(os.listdir())
# Out:
# C:\Users\36175\Question box
# ['.ipynb_checkpoints', 'extract_html.ipynb', 'extract_html.py', 'qa_raw.json', 'query_test.ipynb', 'query_test.py', 'Untitled.ipynb']
